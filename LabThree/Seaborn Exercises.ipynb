# %% [markdown]
# Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Download titanic data from build-in data frames

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(x='fare', y='age', data=titanic,  kind="kde");

# %%
sns.distplot(titanic['fare'], kde=False, bins = 20);

# %%
sns.boxplot(x='pclass', y='age', data=titanic, palette='rainbow');

# %%
sns.barplot(x='class', y='fare', hue='alone' , data=titanic, estimator=np.mean);

# %%
sns.barplot(x='alone', y='age' , data=titanic);

# %%
sns.stripplot(x='alive', y='age', hue = 'class', dodge=True , data=titanic);

# %%
sns.heatmap(titanic.corr())

# %%
g = sns.FacetGrid(titanic, col='sex').map(plt.hist, 'fare')

# %% [markdown]
# Build three customized various graphs using knowledge from:
# http://seaborn.pydata.org/tutorial/aesthetics.html

# %%
g = sns.FacetGrid(titanic, col='class', row='sex').map(plt.stem, 'fare')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-48faeb0fd42a> in <module>
# ----> 1 g = sns.FacetGrid(titanic, col='class', row='sex').map(plt.stem, 'fare')
#
# ~/.local/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
#     769         # Finalize the annotations and layout
#
# ~/.local/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     849
#     850         # Draw the plot
# --> 851         func(*plot_args, **plot_kwargs)
#     852
#     853         # Sort out the supporting information
#
# TypeError: stem() got an unexpected keyword argument 'color'
