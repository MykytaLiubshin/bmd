# %% [markdown]
# <h1>Аналіз та обробка БМД</h1>
# <h2>БС-82</h2>
# <h3 style="font-family:sans-serif;">Микита Любшин<h3>

# %% [markdown]
# <h4 style="font-family:sans-serif;"> Візуалізація даних за допомогою бібліотеки Matplotlib </h4>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# <h4 style="font-family:sans-serif;">1. Створіть вектор розміром 11 зі значеннями від 0 до 5. Розрахуйте на
# його основі вектор y (y = x^2).</h4>

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** (1/2)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([0.        , 0.70710678, 1.        , 1.22474487, 1.41421356,
#        1.58113883, 1.73205081, 1.87082869, 2.        , 2.12132034,
#        2.23606798])

# %% [markdown]
# <h4 style="font-family:sans-serif;">2. Побудова графіків.</h4>

# %% [markdown]
# plt.xlabel("X Label")<h4 style="font-family:sans-serif;">2.1 Функціональний метод. Для побудови базового графіку, що
# відображає залежність х від у використовуйте наступну команду:</h4>

# %%
plt.plot(x, y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#subplot usage

plt.subplot(1,2,1)
plt.plot(x,y,"r")

plt.subplot(1,2,2)
plt.plot(y, x, "b")

# %% [markdown]
# <h4 style="font-family:sans-serif;">2.2. Об’єктно-орієнтований метод. Етапи створення графіку:
# - ініціалізуйте створення графіку як об’єкта;
# - додайте до нього поле, для відображення графіка.</h4>

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])

axes.plot(x, y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes = [fig.add_axes([0, 0, 1, 1]), fig.add_axes([0.5, 0.3, 0.4, 0.3])]

axes[0].plot(x, y, 'r')
axes[0].set_xlabel("X label")
axes[0].set_ylabel("Y label")
axes[0].set_title("Title")

axes[1].plot(x, y, 'b')
axes[1].set_xlabel("X label")
axes[1].set_ylabel("Y label")
axes[1].set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig, axes = plt.subplots(nrows=4, ncols=4)

axes[0][0].plot(x,y)
axes[0][1].plot(y,x)
axes[0][2].plot(list(map(lambda el: el*2,x)),y)
axes[0][3].plot(list(map(lambda el: el*3,x)),y)
axes[3][3].plot(list(map(lambda el: el*2,y)),x)
plt.tight_layout()

# %% [markdown]
# <h4>Додання легенди до графіку</h4>

# %%
fig = plt.figure(figsize=(8,4), dpi=100)
axes = fig.add_axes([0, 0, 1, 1])

axes.plot(x, x**2, label="x**2", color="red", lw=2, ls = '--')
axes.plot(x, x**4, label="x**4", color="green", marker='o',
          markersize=10, markerfacecolor= 'y')
axes.set_title("Title")
axes.legend()

# %%
fig.savefig('output.png')

# %%
plt.scatter(x,y);

# %% [markdown]
# Gistogramm

# %%
from random import random
data=[random()*1000 for i in range(100)];
plt.hist(data, alpha=0.5, rwidth=0.5);

# %%
from random import random
data=[[random()*100 for i in range(4)] for i in range(4)]

#Rect box plot
plt.boxplot(data, vert=True, patch_artist=True);
